# %%
import requests
import os
from pprint import PrettyPrinter
import pandas as pd

places_df = pd.read_csv('cook-county-places.csv')
places_string = ",".join([str(x) for x in places_df['place'].values])

payload = {
    'NAME': 'Name',
    'P0030001': 'Total population',
    'P0030002': 'White alone',
    'P0030003': 'Black or African American alone',
    'P0030004': 'American Indian and Alaska Native alone',
    'P0030005': 'Asian alone',
    'P0030006': 'Native Hawaiian and Other Pacific Islander alone',
    'P0030007': 'Some Other Race alone',
    'P0030008': 'Two or More Races'
}
payload_string = ",".join(list(payload.keys()))

pp = PrettyPrinter(indent=4)

params = {'get': payload_string,
         'for': 'place:%s' % places_string,
#          'in': 'county:031 state:17',
         'in': 'state:17',
         'key': os.environ['US_CENSUS_API_KEY']}

r = requests.get('https://api.census.gov/data/2010/sf1', params=params)

# %%
census_df = pd.DataFrame(eval(r.text)[1:], columns=eval(r.text)[0])
census_df = census_df.rename(columns=payload)
display(census_df)
# Out:
#                               Name Total population White alone  \
# 0                    Alsip village            19277       13105
# 1        Arlington Heights village            75101       66266
# 2               Barrington village            10327        9509
# 3         Barrington Hills village             4209        3839
# 4                 Bartlett village            41208       32397
# 5             Bedford Park village              580         486
# 6                 Bellwood village            19071        2648
# 7              Bensenville village            18352       12345
# 8                 Berkeley village             5209        2483
# 9                      Berwyn city            56657       34270
# 10                Blue Island city            23706        9780
# 11              Bridgeview village            16446       13890
# 12               Broadview village             7932        1352
# 13              Brookfield village            18978       16830
# 14           Buffalo Grove village            41496       33122
# 15                    Burbank city            28925       23634
# 16                 Burnham village             4206        1096
# 17              Burr Ridge village            10559        8487
# 18               Calumet City city            37042        7101
# 19            Calumet Park village             7835         519
# 20                    Chicago city          2695598     1212835
# 21            Chicago Heights city            30276       11506
# 22           Chicago Ridge village            14305       11883
# 23                     Cicero town            83891       43579
# 24         Country Club Hills city            16541        1442
# 25                Countryside city             5895        5215
# 26               Crestwood village            10950        9536
# 27               Deerfield village            18225       17124
# 28               Deer Park village             3200        2973
# 29                Des Plaines city            58364       45133
# ..                             ...              ...         ...
# 105              Riverdale village            13549         581
# 106           River Forest village            11172        9475
# 107            River Grove village            10227        8944
# 108              Riverside village             8875        8107
# 109                Robbins village             5337         192
# 110           Rolling Meadows city            24099       18725
# 111                Roselle village            22763       19161
# 112               Rosemont village             4202        3279
# 113           Sauk Village village            10506        2946
# 114             Schaumburg village            74227       52281
# 115          Schiller Park village            11793        9514
# 116                 Skokie village            64784       39045
# 117       South Barrington village             4565        3175
# 118  South Chicago Heights village             4139        2618
# 119          South Holland village            22030        4508
# 120                 Steger village             9570        6854
# 121               Stickney village             6786        4601
# 122             Stone Park village             4946        2254
# 123             Streamwood village            39858       26305
# 124                 Summit village            11054        6386
# 125               Thornton village             2338        1941
# 126            Tinley Park village            56703       50332
# 127        University Park village             7129         436
# 128            Westchester village            16718       12434
# 129        Western Springs village            12975       12554
# 130               Wheeling village            37648       25220
# 131         Willow Springs village             5524        5079
# 132               Wilmette village            27087       23148
# 4                    1017               798    17  04013
# 5                      78                10    17  04572
# 6                    1508               341    17  04975
# 7                    3748               543    17  05248
# 8                     701               158    17  05404
# 9                   15075              1908    17  05573
# 10                   5605               714    17  06704
# 11                   1081               463    17  08225
# 12                    265               149    17  08446
# 13                    905               435    17  08576
# 14                    587               647    17  09447
# 15                   3252               643    17  09642
# 16                    374                78    17  09798
# 17                     96               194    17  09980
# 18                   2742               707    17  10487
# 19                    263                82    17  10513
# 20                 360493             73148    17  14000
# 21                   5036               863    17  14026
# 22                    689               425    17  14065
# 23                  32943              2959    17  14351
# 24                    181               296    17  16691
# 25                    301                88    17  16873
# 26                    344               193    17  17497
# 27                    137               185    17  18992
# 28                     21                40    17  19083
# 29                   3721              1419    17  19642
# ..                    ...               ...   ...    ...
# 105                    71               166    17  64278
# 106                   197               229    17  64304
# 107                   653               197    17  64343
# 108                   288               161    17  64421
# 109                    45                63    17  64616
# 110                  1963               778    17  65338
# 111                   435               467    17  65806
# 112                   545               120    17  65819
# 113                   509               406    17  67769
# 114                  2100              1807    17  68003
# 115                  1080               219    17  68081
# 116                  1994              2362    17  70122
# 117                    25               108    17  70564
# 118                   649               100    17  70629
# 119                   656               335    17  70850
# 120                   429               293    17  72520
# 121                  1710               170    17  72676
# 122                  2252               172    17  72923
# 123                  4219              1196    17  73157
# 124                  2907               412    17  73638
# 125                    77                65    17  75185
# 126                  1140               848    17  75484
# 127                    52               176    17  76935
# 128                   882               299    17  80047
# 129                    69               114    17  80242
# 130                  5417               956    17  81087
# 131                   149                92    17  82049
# 132                   211               572    17  82075
# 133                    41               142    17  82530
# 134                   371               206    17  83518
#
# [135 rows x 11 columns]

# %%
round(census_df['White alone'].astype('int64')/census_df['Total population'].astype('int64'), 2)
# Out:
# 0      0.68
# 1      0.88
# 2      0.92
# 3      0.91
# 4      0.79
# 5      0.84
# 6      0.14
# 7      0.67
# 8      0.48
# 9      0.60
# 10     0.41
# 11     0.84
# 12     0.17
# 13     0.89
# 14     0.80
# 15     0.82
# 16     0.26
# 17     0.80
# 18     0.19
# 19     0.07
# 20     0.45
# 21     0.38
# 22     0.83
# 23     0.52
# 24     0.09
# 25     0.88
# 26     0.87
# 27     0.94
# 28     0.93
# 29     0.77
#        ...
# 105    0.04
# 106    0.85
# 107    0.87
# 108    0.91
# 109    0.04
# 110    0.78
# 111    0.84
# 112    0.78
# 113    0.28
# 114    0.70
# 115    0.81
# 116    0.60
# 117    0.70
# 118    0.63
# 119    0.20
# 120    0.72
# 121    0.68
# 122    0.46
# 123    0.66
# 124    0.58
# 125    0.83
# 126    0.89
# 127    0.06
# 128    0.74
# 129    0.97
# 130    0.67
# 131    0.92
# 132    0.85
# 133    0.95
# 134    0.90
# Length: 135, dtype: float64

# %%
for col in census_df[census_df.columns[2:9]]:
    census_df['Percent %s' % col] = round(census_df[col].astype('int64')/census_df['Total population'].astype('int64'), 2)

# %%
import requests
import os
from pprint import PrettyPrinter
import pandas as pd

places_df = pd.read_csv('cook-county-places.csv')
places_string = ",".join([str(x).zfill(5) for x in places_df['place'].values])
# places_string = '*'

# Variables for ACS 2016 Profile: https://api.census.gov/data/2016/acs/acs5/variables.html
payload = {
    'NAME': 'Name',
    'DP05_0028E': 'Total population',
#     'DP05_0032PE': 'White only',
#     'DP05_0033PE': 'Black or African American only',
#     'DP05_0034PE': 'American Indian and Alaska Native only',
#     'DP05_0039PE': 'Asian only',
#     'DP05_0047PE': 'Native Hawaiian and Other Pacific Islander only',
#     'DP05_0052PE': 'Some other race only',
#     'DP05_0053PE': 'Two or more races only',
    'DP03_0062E': 'Median household income',
    'DP03_0119PE': 'Percent in poverty'
}
payload_string = ",".join(list(payload.keys()))

pp = PrettyPrinter(indent=4)

params = {'get': payload_string,
         'for': 'place:%s' % places_string,
#          'in': 'county:031 state:17',
         'in': 'state:17',
         'key': os.environ['US_CENSUS_API_KEY']}

r = requests.get('https://api.census.gov/data/2016/acs/acs5/profile', params=params)

# %%
census_df = pd.DataFrame(eval(r.text)[1:], columns=eval(r.text)[0])
census_df = census_df.rename(columns=payload)
# census_df['Median household income'] = census_df['Median household income'].astype('int64')
# display(census_df.sort_values(by=['Median household income'], ascending=False))

# %%
for col in census_df:
    try:
        census_df[col] = pd.to_numeric(census_df[col])
    except ValueError:
        pass

# %%
census_df.sort_values(by=['Percent in poverty'])
# Out:
#                                         Name  Total population  \
# 40               Flossmoor village, Illinois              9215
# 43             Forest View village, Illinois               783
# 63               Inverness village, Illinois              7844
# 62        Indian Head Park village, Illinois              3823
# 27               Deerfield village, Illinois             18686
# 129        Western Springs village, Illinois             13133
# 92          Olympia Fields village, Illinois              4888
# 28               Deer Park village, Illinois              3409
# 96              Palos Heights city, Illinois             12544
# 46                 Glencoe village, Illinois              8870
# 49                    Golf village, Illinois               533
# 2               Barrington village, Illinois             10449
# 84              Northbrook village, Illinois             33538
# 132               Wilmette village, Illinois             27367
# 98              Palos Park village, Illinois              4934
# 78        Merrionette Park village, Illinois              1896
# 133               Winnetka village, Illinois             12437
# 59              Homer Glen village, Illinois             24385
# 1        Arlington Heights village, Illinois             75721
# 65              Kenilworth village, Illinois              2613
# 88               Oak Brook village, Illinois              7988
# 100                Park Ridge city, Illinois             37567
# 36                   Elmhurst city, Illinois             45742
# 47                Glenview village, Illinois             46559
# 69                  Lemont village, Illinois             16587
# 131         Willow Springs village, Illinois              5677
# 67          La Grange Park village, Illinois             13596
# 4                 Bartlett village, Illinois             41475
# 14           Buffalo Grove village, Illinois             41554
# 73                  McCook village, Illinois               226
# ..                                       ...               ...
# 120                 Steger village, Illinois              9535
# 19            Calumet Park village, Illinois              8320
# 55                Hillside village, Illinois              8165
# 99             Park Forest village, Illinois             21831
# 53             Hazel Crest village, Illinois             13924
# 118  South Chicago Heights village, Illinois              4143
# 124                 Summit village, Illinois             11409
# 11              Bridgeview village, Illinois             16381
# 122             Stone Park village, Illinois              4936
# 10                Blue Island city, Illinois             22446
# 76                 Maywood village, Illinois             24029
# 18               Calumet City city, Illinois             37112
# 77            Melrose Park village, Illinois             25422
# 20                    Chicago city, Illinois           2714017
# 113           Sauk Village village, Illinois             10541
# 104           Richton Park village, Illinois             13668
# 23                     Cicero town, Illinois             83972
# 22           Chicago Ridge village, Illinois             14368
# 101                Phoenix village, Illinois              2042
# 16                 Burnham village, Illinois              4212
# 112               Rosemont village, Illinois              4715
# 105              Riverdale village, Illinois             13047
# 31                  Dolton village, Illinois             23113
# 74                    Markham city, Illinois             12633
# 109                Robbins village, Illinois              5216
# 21            Chicago Heights city, Illinois             30349
# 102                  Posen village, Illinois              6251
# 30                 Dixmoor village, Illinois              3614
# 51                     Harvey city, Illinois             25625
# 41            Ford Heights village, Illinois              2775
#
#      Median household income  Percent in poverty  state  place
# 40                     87179                 0.0     17  26571
# 43                     57981                 0.0     17  26987
# 63                    172949                 0.0     17  37608
# 62                     82219                 1.1     17  37257
# 27                    143729                 1.1     17  18992
# 129                   147361                 1.1     17  80242
# 92                     96377                 1.2     17  55938
# 28                    160461                 1.3     17  19083
# 96                     80077                 1.5     17  57381
# 46                    185320                 1.6     17  29652
# 49                    168750                 1.6     17  30328
# 2                     119688                 1.8     17   3844
# 84                    115243                 1.8     17  53481
# 132                   138651                 2.1     17  82075
# 98                     77304                 2.2     17  57407
# 78                     48295                 2.2     17  48554
# 133                   207857                 2.3     17  82530
# 59                     92054                 2.3     17  35835
# 1                      79979                 2.5     17   2154
# 65                    211023                 2.6     17  39519
# 88                    144286                 2.6     17  54534
# 100                    92474                 2.9     17  57875
# 36                    100671                 2.9     17  23620
# 47                    102009                 3.0     17  29938
# 69                     89524                 3.0     17  42795
# 131                    81926                 3.0     17  82049
# 67                     85671                 3.2     17  40793
# 4                     100458                 3.2     17   4013
# 14                    101376                 3.2     17   9447
# 73                     50417                 3.4     17  45564
# ..                       ...                 ...    ...    ...
# 120                    42492                13.7     17  72520
# 19                     46351                14.5     17  10513
# 55                     50779                14.5     17  35086
# 99                     44713                14.8     17  57732
# 53                     50661                15.0     17  33695
# 118                    35721                15.4     17  70629
# 124                    47421                15.6     17  73638
# 11                     52810                16.6     17   8225
# 122                    40717                16.9     17  72923
# 10                     41305                17.0     17   6704
# 76                     44126                17.0     17  47774
# 18                     40845                17.1     17  10487
# 77                     45931                17.2     17  48242
# 20                     50434                17.6     17  14000
# 113                    42532                17.9     17  67769
# 104                    53693                18.1     17  63706
# 23                     42345                19.7     17  14351
# 22                     43103                19.8     17  14065
# 101                    33594                20.0     17  59572
# 16                     44048                21.9     17   9798
# 112                    46875                22.2     17  65819
# 105                    31438                22.2     17  64278
# 31                     44511                22.3     17  20292
# 74                     34414                23.1     17  47007
# 109                    30490                23.6     17  64616
# 21                     40611                24.3     17  14026
# 102                    41546                25.6     17  61314
# 30                     43882                30.4     17  20149
# 51                     21909                30.6     17  33383
# 41                     23220                35.2     17  26710
#
# [135 rows x 6 columns]
